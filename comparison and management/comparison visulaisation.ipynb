# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("C:\\Users\\aditya\\Downloads\\Residential_Average_Monthly_kWh_and_Bills.csv")

# %%
# xtrain_encoded = pd.get_dummies(xtrain)
# poitr=pd.get_dummies(poi)
from sklearn.preprocessing import LabelEncoder

# %%
from sklearn.linear_model import LinearRegression

# %%
df
# Out:
#          Date  Average kWh  Fuel Charge (Cents/kWh)  Average Bill
# 0    2000 Jan          820                    1.372         54.26
# 1    2000 Feb          766                    1.372         50.27
# 2    2000 Mar          707                    1.372         45.91
# 3    2000 Apr          715                    1.372         46.50
# 4    2000 May          838                    1.372         61.68
# ..        ...          ...                      ...           ...
# 226  2018 Nov          685                    2.895         68.01
# 227  2018 Dec          663                    2.895         65.67
# 228  2019 Jan          761                    2.895         76.13
# 229  2019 Feb          707                    2.895         70.38
# 230  2019 Mar          658                    2.895         65.13
#
# [231 rows x 4 columns]

# %%
import pandas as pd


rows_per_group = 12

num_groups = len(df) // rows_per_group

sums = [df.iloc[i * rows_per_group : (i + 1) * rows_per_group]['Average Bill'].sum() for i in range(num_groups)]

print (sums)
# Out:
# [919.0400000000001, 1016.1, 899.1800000000001, 914.04, 978.5100000000001, 1037.73, 1143.61, 1034.31, 1128.9900000000002, 1112.8999999999999, 1105.23, 1147.08, 1081.9, 1141.3400000000001, 1169.41, 1178.07, 1069.1100000000001, 1021.41, 1090.24]

# %%
years_list = [year for year in range(2000, 2019)]

print(years_list)
# Out:
# [2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018]

# %%
import math
l=df.shape[0]
# for i in range()
acl=math.floor(l/12)

# %%
# plt.bar(years_list,sums)
# plt.bar(map(str, years_list), sums)
string_numbers = [str(num) for num in years_list]

# %%
from matplotlib.pyplot import style
plt.figure(figsize=(16,16))
style.use("ggplot")
plt.title("Total Bill across years")
plt.xlabel("Years")
plt.ylabel("Total Bill")
plt.plot(string_numbers,sums,color="g",marker="o",linewidth=3)

# %%
acl
row=12

# %%
for i in range(5):
    from matplotlib.pyplot import style
    style.use("ggplot")
    start_idx = i * row
    end_idx = (i + 1) * row
    subset_df = df[start_idx:end_idx]
    plt.figure(figsize=(8,8))
    subset_df["Date"] = subset_df["Date"].str[4:]
    plt.bar(subset_df["Date"],subset_df["Average Bill"])
    plt.xlabel("Months")
    plt.ylabel("Bill")
    plt.title(2000+i)
# Out:
# C:\Users\aditya\AppData\Local\Temp\ipykernel_18524\16351323.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subset_df["Date"] = subset_df["Date"].str[4:]
# C:\Users\aditya\AppData\Local\Temp\ipykernel_18524\16351323.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subset_df["Date"] = subset_df["Date"].str[4:]
# C:\Users\aditya\AppData\Local\Temp\ipykernel_18524\16351323.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...
